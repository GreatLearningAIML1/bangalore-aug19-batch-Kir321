# %%
import numpy as np
import pandas as pd
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense,Dropout,Activation,Flatten
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Reshape, BatchNormalization
#from keras.layers.convolutional import Conv2D,MaxPooling2D
from keras.utils import np_utils
from sklearn import metrics
import matplotlib.pyplot as plt
# %matplotlib inline
import keras

# %matplotlib inline

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow is already loaded. Please restart the runtime to change versions.

# %% [markdown]
# ### Data fetching and understand the train/test splits.

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install -q keras

# %%
import keras

# %%
import h5py
import numpy as np

# %%
h5f = h5py.File('/content/drive/My Drive/SVHN_single_grey1.h5','r')

# %%
# load the data set


# Open the file as readonly. The file should be present inside a directory called "data" in the same folder as code

# Load the training, test and validation set
x_train = h5f['X_train'][:]
y_train = h5f['y_train'][:]
x_test = h5f['X_test'][:]
y_test = h5f['y_test'][:]


# Close this file
h5f.close()

# %%
print("x_train shape", x_train.shape)
print("x_test shape", x_test.shape)
print("y_train shape", y_train.shape)
print("y_test shape", y_test.shape)
# Out:
# x_train shape (42000, 32, 32)
# x_test shape (18000, 32, 32)
# y_train shape (42000,)
# y_test shape (18000,)

# %%
y_train[:50]
# Out:
# array([2, 6, 7, 4, 4, 0, 3, 0, 7, 3, 1, 0, 1, 3, 1, 1, 0, 0, 8, 4, 6, 5,
#        7, 9, 1, 0, 3, 0, 7, 2, 1, 1, 0, 2, 9, 0, 2, 5, 1, 3, 2, 7, 9, 8,
#        4, 9, 4, 5, 9, 3], dtype=uint8)

# %%
#Represent Training & Testing samples suitable for #tensorflow backend
#Encoding the output class label (One-Hot Encoding)
x_train = x_train.reshape(x_train.shape[0], 32, 32, 1).astype('float32')
x_test = x_test.reshape(x_test.shape[0], 32, 32, 1).astype('float32')
x_train /= 255
x_test /= 255
y_train = np_utils.to_categorical(y_train, 10)
y_test = np_utils.to_categorical(y_test, 10)

print('--- THE DATA ---')
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# --- THE DATA ---
# x_train shape: (42000, 32, 32, 1)
# 42000 train samples
# 18000 test samples

# %%
BATCH_SIZE = 1000
EPOCHS = 20

# %%
from keras.layers import LeakyReLU
from keras.models import Sequential
import numpy as np
from tensorflow.python import keras

# %%
    from keras.layers import LeakyReLU
    # Define the Type of Model
    model = Sequential()


    # Flatten Imgaes to Vector
    model.add(Reshape((1024,), input_shape=(32, 32, 1)))

    # Layer 1
    model.add(Dense(output_dim=2048, init='he_normal', bias=True))
    model.add(Activation("relu"))
    model.add(Dropout(0.2))
    
    #Layer 1
    model.add(Dense(output_dim=1024, init='he_normal', bias=True))
    model.add(Activation("relu"))
    model.add(Dropout(0.2))

    # Layer 2
    model.add(Dense(output_dim=10, init='he_normal', bias=True))
    model.add(Activation("softmax"))

    # Loss and Optimizer
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    ## Store Training Results
    early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5, verbose=1, mode='auto')
    callback_list = [early_stopping]# [stats, early_stopping]

    # Train the model
    model.fit(x_train, y_train, nb_epoch=EPOCHS, batch_size=BATCH_SIZE,
              validation_data=(x_test, y_test), verbose=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=2048, kernel_initializer="he_normal", use_bias=True)`
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=1024, kernel_initializer="he_normal", use_bias=True)`
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=10, kernel_initializer="he_normal", use_bias=True)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 42000 samples, validate on 18000 samples
# Epoch 1/20
# 42000/42000 [==============================] - 23s 538us/step - loss: 2.7098 - acc: 0.1088 - val_loss: 2.2928 - val_acc: 0.1429
# Epoch 2/20
# 42000/42000 [==============================] - 22s 528us/step - loss: 2.2278 - acc: 0.1830 - val_loss: 2.0584 - val_acc: 0.3364
# Epoch 3/20
# 42000/42000 [==============================] - 22s 519us/step - loss: 1.8792 - acc: 0.3559 - val_loss: 1.5905 - val_acc: 0.5154
# Epoch 4/20
# 42000/42000 [==============================] - 22s 515us/step - loss: 1.5319 - acc: 0.4982 - val_loss: 1.2936 - val_acc: 0.6131
# Epoch 5/20
# 42000/42000 [==============================] - 22s 522us/step - loss: 1.3291 - acc: 0.5727 - val_loss: 1.1878 - val_acc: 0.6317
# Epoch 6/20
# 42000/42000 [==============================] - 23s 549us/step - loss: 1.2107 - acc: 0.6172 - val_loss: 1.1045 - val_acc: 0.6483
# Epoch 7/20
# 42000/42000 [==============================] - 22s 534us/step - loss: 1.1282 - acc: 0.6449 - val_loss: 1.0158 - val_acc: 0.6899
# Epoch 8/20
# 42000/42000 [==============================] - 22s 521us/step - loss: 1.0640 - acc: 0.6696 - val_loss: 1.0059 - val_acc: 0.6895
# Epoch 9/20
# 42000/42000 [==============================] - 22s 528us/step - loss: 1.0285 - acc: 0.6813 - val_loss: 0.9362 - val_acc: 0.7172
# Epoch 10/20
# 42000/42000 [==============================] - 22s 527us/step - loss: 0.9944 - acc: 0.6917 - val_loss: 0.9109 - val_acc: 0.7238
# Epoch 11/20
# 42000/42000 [==============================] - 22s 513us/step - loss: 0.9405 - acc: 0.7109 - val_loss: 0.8687 - val_acc: 0.7392
# Epoch 12/20
# 42000/42000 [==============================] - 22s 514us/step - loss: 0.9075 - acc: 0.7244 - val_loss: 0.8556 - val_acc: 0.7456
# Epoch 13/20
# 42000/42000 [==============================] - 22s 531us/step - loss: 0.8818 - acc: 0.7321 - val_loss: 0.8282 - val_acc: 0.7535
# Epoch 14/20
# 42000/42000 [==============================] - 22s 520us/step - loss: 0.8646 - acc: 0.7339 - val_loss: 0.8052 - val_acc: 0.7592
# Epoch 15/20
# 42000/42000 [==============================] - 22s 515us/step - loss: 0.8481 - acc: 0.7386 - val_loss: 0.8139 - val_acc: 0.7536
# Epoch 16/20
# 42000/42000 [==============================] - 21s 510us/step - loss: 0.8260 - acc: 0.7475 - val_loss: 0.7774 - val_acc: 0.7718
# Epoch 17/20
# 42000/42000 [==============================] - 22s 523us/step - loss: 0.8019 - acc: 0.7562 - val_loss: 0.7738 - val_acc: 0.7668
# Epoch 18/20
# 42000/42000 [==============================] - 21s 510us/step - loss: 0.7969 - acc: 0.7547 - val_loss: 0.7600 - val_acc: 0.7757
# Epoch 19/20
# 42000/42000 [==============================] - 22s 516us/step - loss: 0.7986 - acc: 0.7557 - val_loss: 0.7643 - val_acc: 0.7720
# Epoch 20/20
# 42000/42000 [==============================] - 22s 529us/step - loss: 0.7738 - acc: 0.7628 - val_loss: 0.7452 - val_acc: 0.7782

# %% [markdown]
# # **DNN Using Batch Normalization**

# %%
    from keras.layers import LeakyReLU
    # Define the Type of Model
    model_2 = Sequential()


    # Flatten Imgaes to Vector
    model_2.add(Reshape((1024,), input_shape=(32, 32, 1)))

    # Layer 1
    model_2.add(Dense(output_dim=2048, init='he_normal', bias=False))
    model_2.add(BatchNormalization())
    model_2.add(Activation("relu"))
    model_2.add(Dropout(0.2))
    
    #Layer 1
    model_2.add(Dense(output_dim=1024, init='he_normal', bias=False))
    model_2.add(BatchNormalization())
    model_2.add(Activation("relu"))
    model_2.add(Dropout(0.2))

    # Layer 2
    model_2.add(Dense(output_dim=10, init='he_normal', bias=False))
    model_2.add(BatchNormalization())
    model_2.add(Activation("softmax"))

    # Loss and Optimizer
    model_2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    ## Store Training Results
    early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5, verbose=1, mode='auto')
    callback_list = [early_stopping]# [stats, early_stopping]

    # Train the model
    model_2.fit(x_train, y_train, nb_epoch=EPOCHS, batch_size=BATCH_SIZE,
              validation_data=(x_test, y_test), verbose=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=2048, kernel_initializer="he_normal", use_bias=False)`
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=1024, kernel_initializer="he_normal", use_bias=False)`
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=10, kernel_initializer="he_normal", use_bias=False)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:35: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 42000 samples, validate on 18000 samples
# Epoch 1/20
# 42000/42000 [==============================] - 25s 589us/step - loss: 1.5864 - acc: 0.5147 - val_loss: 1.5669 - val_acc: 0.5286
# Epoch 2/20
# 42000/42000 [==============================] - 23s 558us/step - loss: 1.0893 - acc: 0.7210 - val_loss: 1.4999 - val_acc: 0.6057
# Epoch 3/20
# 42000/42000 [==============================] - 23s 557us/step - loss: 0.9472 - acc: 0.7679 - val_loss: 1.4618 - val_acc: 0.6487
# Epoch 4/20
# 42000/42000 [==============================] - 23s 557us/step - loss: 0.8555 - acc: 0.7955 - val_loss: 1.3638 - val_acc: 0.7297
# Epoch 5/20
# 42000/42000 [==============================] - 24s 560us/step - loss: 0.7932 - acc: 0.8119 - val_loss: 1.3288 - val_acc: 0.6582
# Epoch 6/20
# 42000/42000 [==============================] - 23s 556us/step - loss: 0.7424 - acc: 0.8259 - val_loss: 1.2919 - val_acc: 0.6894
# Epoch 7/20
# 42000/42000 [==============================] - 24s 561us/step - loss: 0.7073 - acc: 0.8332 - val_loss: 1.2276 - val_acc: 0.6511
# Epoch 8/20
# 42000/42000 [==============================] - 24s 560us/step - loss: 0.6646 - acc: 0.8439 - val_loss: 1.1980 - val_acc: 0.6291
# Epoch 9/20
# 42000/42000 [==============================] - 24s 567us/step - loss: 0.6328 - acc: 0.8498 - val_loss: 1.1990 - val_acc: 0.6863
# Epoch 10/20
# 42000/42000 [==============================] - 23s 559us/step - loss: 0.5953 - acc: 0.8620 - val_loss: 1.1386 - val_acc: 0.6965
# Epoch 11/20
# 42000/42000 [==============================] - 23s 549us/step - loss: 0.5721 - acc: 0.8651 - val_loss: 1.1730 - val_acc: 0.6498
# Epoch 12/20
# 42000/42000 [==============================] - 23s 553us/step - loss: 0.5512 - acc: 0.8698 - val_loss: 1.1594 - val_acc: 0.6558
# Epoch 13/20
# 42000/42000 [==============================] - 23s 551us/step - loss: 0.5149 - acc: 0.8809 - val_loss: 0.9877 - val_acc: 0.7518
# Epoch 14/20
# 42000/42000 [==============================] - 23s 555us/step - loss: 0.5096 - acc: 0.8804 - val_loss: 1.0835 - val_acc: 0.7137
# Epoch 15/20
# 42000/42000 [==============================] - 23s 555us/step - loss: 0.4925 - acc: 0.8831 - val_loss: 0.9991 - val_acc: 0.7684
# Epoch 16/20
# 42000/42000 [==============================] - 23s 553us/step - loss: 0.4610 - acc: 0.8910 - val_loss: 1.1775 - val_acc: 0.6639
# Epoch 17/20
# 42000/42000 [==============================] - 23s 549us/step - loss: 0.4476 - acc: 0.8942 - val_loss: 1.0402 - val_acc: 0.7360
# Epoch 18/20
# 42000/42000 [==============================] - 23s 543us/step - loss: 0.4236 - acc: 0.9012 - val_loss: 1.0678 - val_acc: 0.6939
# Epoch 19/20
# 42000/42000 [==============================] - 23s 551us/step - loss: 0.4136 - acc: 0.9036 - val_loss: 1.0215 - val_acc: 0.7344
# Epoch 20/20
# 42000/42000 [==============================] - 23s 555us/step - loss: 0.3927 - acc: 0.9075 - val_loss: 1.0270 - val_acc: 0.7269
